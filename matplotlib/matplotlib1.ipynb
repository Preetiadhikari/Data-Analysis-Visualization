# %%
import matplotlib .pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

# %%
plt.xlabel('Day')
plt.ylabel('temperature')
plt.title('Weather')
plt.plot(x,y,color="green",linewidth=5,linestyle="dotted")

# %%
plt.plot(x,y,'--r')

# %%
plt.plot(x,y,color='black',marker='D',linestyle='',markersize=10,alpha=0.55)
